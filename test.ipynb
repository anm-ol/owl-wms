# %%
import numpy as np

try:
    # Try to load the data, assuming 'data.npz' exists
    data = np.load('t3_data/tekken_dataset_npz/round_001.npz')
    print("Data loaded successfully from data.npz")
    # You can access the arrays within the loaded data like this:
    # array1 = data['array1']
    # array2 = data['array2']
except FileNotFoundError:
    print("Error: data.npz not found. Please make sure the file exists in the current directory.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data loaded successfully from data.npz

# %%
# Out:
# [1 1 1 ... 0 0 0]

# %%
import matplotlib.pyplot as plt

mask = data['attention_mask']
for i, x in enumerate(mask):
    if x == 0:
        print(f"Mask at index {i} is 0")
# Out:
# Mask at index 313 is 1
# Mask at index 314 is 1
# Mask at index 315 is 1
# Mask at index 316 is 1
# Mask at index 317 is 1
# Mask at index 318 is 1
# Mask at index 319 is 1
# Mask at index 320 is 1
# Mask at index 321 is 1
# Mask at index 322 is 1
# Mask at index 323 is 1
# Mask at index 324 is 1
# Mask at index 325 is 1
# Mask at index 326 is 1
# Mask at index 327 is 1
# Mask at index 328 is 1
# Mask at index 329 is 1
# Mask at index 330 is 1
# Mask at index 331 is 1
# Mask at index 332 is 1
# Mask at index 333 is 1
# Mask at index 334 is 1
# Mask at index 335 is 1
# Mask at index 336 is 1
# Mask at index 337 is 1
# Mask at index 338 is 1
# Mask at index 339 is 1
# Mask at index 340 is 1
# Mask at index 341 is 1
# Mask at index 342 is 1
# Mask at index 343 is 1
# Mask at index 344 is 1
# Mask at index 345 is 1
# Mask at index 346 is 1
# Mask at index 347 is 1
# Mask at index 348 is 1
# Mask at index 349 is 1
# Mask at index 350 is 1
# Mask at index 351 is 1
# Mask at index 352 is 1
# ...
